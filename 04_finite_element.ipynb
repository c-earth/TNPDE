# %% [markdown]
# # Finite element management
#
# This notebook demonstrates the application of `FiniteElement` class from `/utils/finite_element.py`. Conceptually, the class serve as the manager for all of the elements in the simulation. Specifically, it manage the transformation between each element's simplex and the standard one, generate the boundary conditions for both the boundaries between elements and the boundaries between elements at simulation edge and the environment.
